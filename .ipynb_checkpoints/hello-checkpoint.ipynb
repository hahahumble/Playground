# %%
print("Hello")
x = 2
# Out:
# Hello

# %%
class A:
    def __init__(self):
        pass

    def func(self):
        pass

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# /notebooks/Playground

# %%
data_dir = Path("../Data")
# Out:
# ../Data

# %%
# %ls ../Data
# Out:
# FashionMNIST_builtin/  mnist_train/
